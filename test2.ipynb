# %%
import pandas as pd
import matplotlib.pyplot as plt
import stemgraphic 
import seaborn as sns
import scipy.stats as stats

# %%
cols = ['แรงม้า','เงินทุนรวม','คนงานรวม']
dataset = pd.read_csv('hp_no_outlier.csv',encoding='utf-8',usecols=cols)
print(dataset)
# Out:
#       เงินทุนรวม  คนงานรวม  แรงม้า
# 0     20000000.0       5.0  270.68
# 1     43100000.0      10.0  356.00
# 2      8035000.0       1.0   83.05
# 3      5500000.0      13.0  191.00
# 4      6000000.0      25.0  167.25
# ...          ...       ...     ...
# 1509   3600000.0       6.0  178.00
# 1510   8000000.0      18.0   83.00
# 1511  15700000.0       8.0  301.29
# 1512  45000000.0      15.0  278.50
# 1513   3500000.0      22.0  115.50
#
# [1514 rows x 3 columns]

# %%
dataset.describe()
# Out:
#          เงินทุนรวม     คนงานรวม       แรงม้า
# count  1.514000e+03  1514.000000  1514.000000
# mean   1.121034e+07    11.321424   221.513156
# std    9.757730e+06     5.798987   156.663836
# min    1.500000e+05     1.000000    15.200000
# 25%    4.000000e+06     7.000000    95.000000
# 50%    8.000000e+06    10.000000   171.750000
# 75%    1.500000e+07    15.000000   296.850000
# max    4.540750e+07    29.000000   686.500000

# %%
dataset.mode()
# Out:
#    เงินทุนรวม  คนงานรวม  แรงม้า
# 0  10000000.0      10.0    90.0

# %%
dataset.median()
# Out:
# เงินทุนรวม    8000000.00
# คนงานรวม           10.00
# แรงม้า            171.75
# dtype: float64

# %%
dataset.var()
# Out:
# เงินทุนรวม    9.521330e+13
# คนงานรวม      3.362825e+01
# แรงม้า        2.454356e+04
# dtype: float64

# %%
ranges = dataset.max() - dataset.min()
print(ranges)
# Out:
# เงินทุนรวม    45257500.0
# คนงานรวม            28.0
# แรงม้า             671.3
# dtype: float64

# %%
p = sns.boxplot( dataset['คนงานรวม'])
p.set_xlabel('คนงานรวม (คน)')
# Out:
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'คนงานรวม (คน)')
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.boxplot(dataset['แรงม้า'])
# Out:
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='แรงม้า'>
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.hist(dataset['คนงานรวม'], bins=39)
# Out:
# (array([  3.,  17.,  43.,   0.,  75.,  88.,  79.,   0., 131.,  98.,   0.,
#          78., 257.,  53.,   0., 102.,  37.,   0.,  47., 101.,  23.,   0.,
#          22.,  32.,   0.,  13., 107.,  13.,   0.,  22.,   5.,   0.,   8.,
#          36.,   6.,   0.,   9.,   7.,   2.]),
#  array([ 1.        ,  1.71794872,  2.43589744,  3.15384615,  3.87179487,
#          4.58974359,  5.30769231,  6.02564103,  6.74358974,  7.46153846,
#          8.17948718,  8.8974359 ,  9.61538462, 10.33333333, 11.05128205,
#         11.76923077, 12.48717949, 13.20512821, 13.92307692, 14.64102564,
#         15.35897436, 16.07692308, 16.79487179, 17.51282051, 18.23076923,
#         18.94871795, 19.66666667, 20.38461538, 21.1025641 , 21.82051282,
#         22.53846154, 23.25641026, 23.97435897, 24.69230769, 25.41025641,
#         26.12820513, 26.84615385, 27.56410256, 28.28205128, 29.        ]),
#  <BarContainer object of 39 artists>)

# %%
plt.hist(dataset['แรงม้า'], bins=39)
# Out:
# (array([  1.,   3., 129., 138., 176.,  57., 108.,  66.,  75.,  62.,  75.,
#          46.,  47.,  42.,  33.,  57.,  37.,  22.,  25.,  26.,  23.,  30.,
#          19.,  22.,  12.,  20.,  16.,  30.,  22.,   9.,  10.,   5.,  14.,
#          11.,   6.,   8.,   1.,  12.,  19.]),
#  array([ 15.2       ,  32.41282051,  49.62564103,  66.83846154,
#          84.05128205, 101.26410256, 118.47692308, 135.68974359,
#         152.9025641 , 170.11538462, 187.32820513, 204.54102564,
#         221.75384615, 238.96666667, 256.17948718, 273.39230769,
#         290.60512821, 307.81794872, 325.03076923, 342.24358974,
#         359.45641026, 376.66923077, 393.88205128, 411.09487179,
#         428.30769231, 445.52051282, 462.73333333, 479.94615385,
#         497.15897436, 514.37179487, 531.58461538, 548.7974359 ,
#         566.01025641, 583.22307692, 600.43589744, 617.64871795,
#         634.86153846, 652.07435897, 669.28717949, 686.5       ]),
#  <BarContainer object of 39 artists>)

# %%
stemgraphic.stem_graphic(dataset['คนงานรวม'])
# Out:
# (<Figure size 540x1080 with 1 Axes>, <Axes:>)

# %%
stemgraphic.stem_graphic(dataset['แรงม้า'],scale=10)
# Out:
# (<Figure size 540x1278 with 1 Axes>, <Axes:>)

# %%
plt.scatter(dataset['คนงานรวม'],dataset['เงินทุนรวม'])

# %%
plt.scatter(dataset['แรงม้า'],dataset['เงินทุนรวม'])

# %%
sns.ecdfplot(data=dataset['คนงานรวม'])
# Out:
# <AxesSubplot:xlabel='คนงานรวม', ylabel='Proportion'>
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.ecdfplot(data=dataset['แรงม้า'])
# Out:
# <AxesSubplot:xlabel='แรงม้า', ylabel='Proportion'>
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
pd.DataFrame(data=dataset['คนงานรวม']).plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
pd.DataFrame(data=dataset['แรงม้า']).plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LENOVO LEGION\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 3617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
