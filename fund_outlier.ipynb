# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['แรงม้า','เงินทุนรวม','คนงานรวม']
dataset = pd.read_csv('hp_no_outlier.csv',encoding='utf-8',usecols=cols)
dataset
# Out:
#       เงินทุนรวม  คนงานรวม  แรงม้า
# 0     20000000.0       5.0  270.68
# 1     43100000.0      10.0  356.00
# 2      8035000.0       1.0   83.05
# 3      5500000.0      13.0  191.00
# 4      6000000.0      25.0  167.25
# ...          ...       ...     ...
# 1509   3600000.0       6.0  178.00
# 1510   8000000.0      18.0   83.00
# 1511  15700000.0       8.0  301.29
# 1512  45000000.0      15.0  278.50
# 1513   3500000.0      22.0  115.50
#
# [1514 rows x 3 columns]

# %%
dataset.describe()
# Out:
#          เงินทุนรวม     คนงานรวม       แรงม้า
# count  1.514000e+03  1514.000000  1514.000000
# mean   1.121034e+07    11.321424   221.513156
# std    9.757730e+06     5.798987   156.663836
# min    1.500000e+05     1.000000    15.200000
# 25%    4.000000e+06     7.000000    95.000000
# 50%    8.000000e+06    10.000000   171.750000
# 75%    1.500000e+07    15.000000   296.850000
# max    4.540750e+07    29.000000   686.500000

# %%
dataset.mode()
# Out:
#    เงินทุนรวม  คนงานรวม  แรงม้า
# 0  10000000.0      10.0    90.0

# %%
Q1_fund = dataset['เงินทุนรวม'].quantile(0.25)
Q3_fund = dataset['เงินทุนรวม'].quantile(0.75)
Q1_fund,Q3_fund
# Out:
# (4000000.0, 15000000.0)

# %%
IQR_fund = Q3_fund - Q1_fund
IQR_fund
# Out:
# 11000000.0

# %%
lower_outlier_fund = Q1_fund - 1.5*IQR_fund
upper_outlier_fund = Q3_fund + 1.5*IQR_fund
lower_outlier_fund, upper_outlier_fund
# Out:
# (-12500000.0, 31500000.0)

# %%
dataset[(dataset['เงินทุนรวม'] < lower_outlier_fund)|(dataset['เงินทุนรวม'] > upper_outlier_fund)]
# Out:
#         เงินทุนรวม   คนงานรวม      แรงม้า
# 1     4.310000e+07  10.000000  356.000000
# 8     3.160000e+07   8.000000  375.000000
# 41    4.350000e+07  20.000000   60.000000
# 68    4.000000e+07  20.000000  568.000000
# 85    3.500000e+07   9.000000  570.000000
# ...            ...        ...         ...
# 1448  3.835523e+07  22.421477  684.243152
# 1449  3.835523e+07  22.421477  684.243152
# 1450  3.835523e+07  22.421477  684.243152
# 1462  4.500000e+07  10.000000  315.180000
# 1512  4.500000e+07  15.000000  278.500000
#
# [86 rows x 3 columns]

# %%
dataset[(dataset['เงินทุนรวม'] > lower_outlier_fund) & (dataset['เงินทุนรวม'] < upper_outlier_fund)]
# Out:
#       เงินทุนรวม  คนงานรวม  แรงม้า
# 0     20000000.0       5.0  270.68
# 2      8035000.0       1.0   83.05
# 3      5500000.0      13.0  191.00
# 4      6000000.0      25.0  167.25
# 5     13200000.0      20.0  130.00
# ...          ...       ...     ...
# 1508   3800000.0       3.0   70.00
# 1509   3600000.0       6.0  178.00
# 1510   8000000.0      18.0   83.00
# 1511  15700000.0       8.0  301.29
# 1513   3500000.0      22.0  115.50
#
# [1427 rows x 3 columns]

# %%
fund_no_outlier = dataset[(dataset['เงินทุนรวม'] > lower_outlier_fund) & (dataset['เงินทุนรวม'] < upper_outlier_fund)]
fund_no_outlier
# Out:
#       เงินทุนรวม  คนงานรวม  แรงม้า
# 0     20000000.0       5.0  270.68
# 2      8035000.0       1.0   83.05
# 3      5500000.0      13.0  191.00
# 4      6000000.0      25.0  167.25
# 5     13200000.0      20.0  130.00
# ...          ...       ...     ...
# 1508   3800000.0       3.0   70.00
# 1509   3600000.0       6.0  178.00
# 1510   8000000.0      18.0   83.00
# 1511  15700000.0       8.0  301.29
# 1513   3500000.0      22.0  115.50
#
# [1427 rows x 3 columns]

# %%
fund_no_outlier.describe()
# Out:
#          เงินทุนรวม     คนงานรวม       แรงม้า
# count  1.427000e+03  1427.000000  1427.000000
# mean   9.590783e+06    11.060967   213.140332
# std    7.387916e+06     5.668476   148.633830
# min    1.500000e+05     1.000000    15.200000
# 25%    4.000000e+06     7.000000    94.000000
# 50%    7.500000e+06    10.000000   167.500000
# 75%    1.350000e+07    15.000000   288.500000
# max    3.130000e+07    29.000000   686.500000

# %%
fund_no_outlier.mode()
# Out:
#    เงินทุนรวม  คนงานรวม  แรงม้า
# 0  10000000.0      10.0    90.0

# %%
fund_no_outlier.to_csv(r'./fund_no_outlier.csv')
